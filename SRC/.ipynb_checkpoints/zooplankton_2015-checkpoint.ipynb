# %%
# imporing necessary packages
import pandas as pd
import numpy as np
import sympy.mpmath as math
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import pylab
from matplotlib.dates import DateFormatter
# %matplotlib inline

# %%
def data_load(filename):
    '''Loads data in CSV format, produces pandas dataframe for data, 
    and converts index to datetime, only input required is 
     the file paths'''
    ''' input must have date column labeled 'DATE', and the file path 
    must be in quotes'''
    
    assert type(filename) == str, 'filename_1 should be a string'

    # loading the first dataset and changing the index column to the date
    dataset = pd.read_csv(filename, sep=',', index_col='DATE')
    # converting the date index to datetime
    dataset.index = pd.to_datetime(dataset.index)
    
    return dataset

# %%
# loading 2015 zooplankton data
zoo_2015 = data_load('../Data/zooplankton_2015.csv')

# %%
# checking out the 2015 zooplankton data
zoo_2015.head()
# Out:
#             Cnidaria  Ctenophora  Copoepoda  Cirripedia  Ostracoda  \
# Date
# 2015-04-01        16           1        834         157         90
# 2015-04-07         5           0        742          11          7
# 2015-05-08         8           0        879         456         83
# 2015-05-14         0           1        712         131         71
# 2015-05-22         0           1       1020         361        124
#
#             Branchiopoda  Malacostraca  Bryozoan  Phorinida  Chaetognatha  \
# Date
# 2015-04-01             0           161        76          8             2
# 2015-04-07             0            12        47          0            14
# 2015-05-08             0           149       101         24             4
# 2015-05-14             0            23        15          0             0
# 2015-05-22             0            45        35          0             0
#
#             Chordata  Mollusca  Echinodermata  Urochordata  Annelids  Eggs  \
# Date
# ...

# %%
# laoding the 2015 temeprature data
temp_2015 = data_load('../Data/temp_2015.csv')

# %%
# checking out the 2015 temperature data
temp_2015.head()
# Out:
#              m_0   m_1   m_2   m_3   m_4   m_5   m_6   m_7   m_8   m_9  m_10
# Date
# 2015-04-07   9.7   9.6   9.6   9.6   9.5   9.5   9.5   9.5   9.5   9.5   9.5
# 2015-04-14   9.6   9.6   9.5   9.5   9.5   9.5   9.5   9.5   9.5   9.5   9.5
# 2015-04-29   9.9   9.9   9.8   9.8   9.8   9.8   9.8   9.8   9.8   9.8   9.8
# 2015-05-08  11.6  11.5  11.5  11.5  11.5  11.4  11.5  11.5  10.7  10.6  10.3
# 2015-05-14  10.3  10.3  10.3  10.3  10.2  10.2  10.2  10.2  10.2  10.2  10.2

# %%
# loading the 2015 salinity data
sal_2015 = data_load('../Data/Salinity_2015.csv')

# %%
# checking out the 2015 salinity data
sal_2015.head()
# Out:
#              m_0   m_1   m_2   m_3   m_4   m_5   m_6   m_7   m_8   m_9  m_10
# Date
# 2015-04-07  20.4  22.7  23.4  23.9  24.5  24.8  24.9  25.1  25.2  25.3  25.2
# 2015-04-14  24.9  25.7  25.8  25.9  26.1  26.1  26.2  26.3  26.4  26.4  26.4
# 2015-04-29  25.3  25.8  25.9  26.2  26.3  26.3  26.3  26.4  26.4  26.4  26.4
# 2015-05-08  25.3  25.8  25.9  26.2  26.3  26.3  26.3  26.4  26.4  26.4  26.4
# 2015-05-14  26.6  26.6  26.6  26.6  26.6  26.6  26.6  26.6  26.6  26.6  26.6

# %%
# loading the 2015 dissolved oxygen data
dis_oxy_2015 = data_load('../Data/dissolved_oxygen_2015.csv')

# %%
# checking out the 2015 dissolved oxygen data
dis_oxy_2015.head()
# Out:
#              m_0   m_1   m_2   m_3   m_4   m_5   m_6   m_7   m_8   m_9  m_10
# Date
# 2015-04-07  8.51  8.30  7.72  7.69  7.20  7.16  6.84  7.01  7.17  7.26  7.24
# 2015-04-14  8.05  7.80  7.96  8.09  8.31  8.25  8.26  8.30  8.29  8.16  8.18
# 2015-04-29  7.92  7.86  7.80  7.82  7.80  7.80  7.80  7.80  7.80  7.80  7.80
# 2015-05-08  8.74  8.53  8.46  8.45  8.51  8.49  8.48  8.51  7.93  7.48  6.67
# 2015-05-14  6.68  6.67  6.64  6.65  6.69  6.66  6.62  6.63  6.63  6.63  6.63

# %%
# plotting the zooplankton abundance in the Discovery Passage over time 

# setting the figure size
fig = plt.figure(figsize=(12, 5))

# adding a title to the graph
plt.suptitle('Zooplankton Abundance in the Discovery Passage', fontsize=24, y=1.05)

# plotting the zooplankton over time
plt.plot(zoo_2015.index, zoo_2015.Total, 'maroon', linewidth=2.2)

# labeling the x and y axes
plt.xlabel('Date', fontsize=16, )
plt.ylabel('Zooplankton Abundance', fontsize=16)

# setting the extremities to the y axis
plt.ylim([0, 2500])

# saving figure to results
plt.savefig('../Results/zooplankton_abundance.pdf')

plt.show()

# %%
# setting figure size 
fig = plt.figure(figsize=(12, 7))

# Adding a title to the graph
plt.suptitle('2015 Zooplankton and Water Temperature', fontsize=30, y=1.05)

# layering the three axes, which contain the three varaibles, on top of one another to create a single subplot
# layering completed with twinx() method
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()


# plotting the 3 variables into the predetermined plot outlined above
# Setting the color and width of lines on the graph
ax1.plot(zoo_2015.index, zoo_2015.Total, 'maroon', linewidth =3)
ax2.plot(temp_2015.index, temp_2015.m_0, 'sage', linewidth=3)
ax3.plot(temp_2015.index, temp_2015.m_5, 'darkgreen', linewidth=3)
ax4.plot(temp_2015.index, temp_2015.m_10, 'darkslategray', linewidth=3)

# Adjusting the color and size of the axes ticks
ax1.xaxis.set_tick_params(labelcolor='k', size=18)
ax1.yaxis.set_tick_params(labelcolor='k', size=18)
ax2.yaxis.set_tick_params(labelcolor='k', size=18)

# removing the axes ticks on the left and bottom of the graph
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

# removing the axes ticks from the other spines of data
#ax2.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax4.yaxis.set_visible(False)

# Making axes labels, selecting their color, and selecting their size
ax1.set_xlabel('Date', fontsize=20)
ax1.set_ylabel('Zooplankton Abundance' + ' (/m$^3$)', fontsize = 18, color ='k')
ax2.set_ylabel('Water Temperature' + ' ($^o$C)', fontsize = 18, color='k')

# creating handles for each of the lines in the graph. This is in preperation for making a legend
maroon_do_line = mlines.Line2D([], [], color='maroon', marker='', linewidth=3, markersize=20, label='Zooplankton Abundance')
sage_do_line = mlines.Line2D([], [], color='sage', marker='', linewidth=3, markersize=20, label='Water temperature at Surface')
darkgreen_do_line = mlines.Line2D([], [], color='darkgreen', marker='', linewidth=3, markersize=20, label='Water temperature at 5m depth')
darkslategray_do_line = mlines.Line2D([], [], color='darkslategray', marker='', linewidth=3, markersize=20, label='Water temperature at 10m depth')

# Putting handles in legend
plt.legend(handles=[maroon_do_line, sage_do_line, darkgreen_do_line, darkslategray_do_line])

# setting numberical limits on the axes
ax1.set_ylim(0,3000)
ax2.set_ylim(9,15)
ax3.set_ylim(9,15)
ax4.set_ylim(9,15)

# saving figure to results
plt.savefig('../Results/zoo_15_T.pdf')

plt.show()

# %%
fig = plt.figure(figsize=(12, 7))

# Adding a title to the graph
plt.suptitle('2015 Zooplankton and Salinity', fontsize=30, y=1.05)

# layering the three axes, which contain the three varaibles, on top of one another to create a single subplot
# layering completed with twinx() method
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()


# plotting the 3 variables into the predetermined plot outlined above
# Setting the color and width of lines on the graph
ax1.plot(zoo_2015.index, zoo_2015.Total, 'maroon', linewidth =3)
ax2.plot(sal_2015.index, sal_2015.m_0, 'sage', linewidth=3)
ax3.plot(sal_2015.index, sal_2015.m_5, 'darkgreen', linewidth=3)
ax4.plot(sal_2015.index, sal_2015.m_10, 'darkslategray', linewidth=3)

# Adjusting the color of the axes ticks to match line color
ax1.xaxis.set_tick_params(labelcolor='k', size=18)
ax1.yaxis.set_tick_params(labelcolor='k', size=18)
ax2.yaxis.set_tick_params(labelcolor='k', size=18)

# removing the axes ticks on the left and bottom of the graph
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

# removing the axes ticks from the other spines of data
#ax2.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax4.yaxis.set_visible(False)

# Making axes labels, selecting their color, and selecting their size
ax1.set_xlabel('Date', fontsize=20)
ax1.set_ylabel('Zooplankton Abundance' + ' (/m$^3$)', fontsize = 18, color ='k')
ax2.set_ylabel('Salinity' + ' (ppt)', fontsize = 18, color ='k')

# creating handles for each of the lines in the graph. This is in preperation for making a legend
maroon_do_line = mlines.Line2D([], [], color='maroon', marker='', linewidth=3, markersize=20, label='Zooplankton Abundance')
sage_do_line = mlines.Line2D([], [], color='sage', marker='', linewidth=3, markersize=20, label='Salinity at Surface')
darkgreen_do_line = mlines.Line2D([], [], color='darkgreen', marker='', linewidth=3, markersize=20, label='Salnity at 5m depth')
darkslategray_do_line = mlines.Line2D([], [], color='darkslategray', marker='', linewidth=3, markersize=20, label='Salinity at 10m depth')

# Putting handles in legend
plt.legend(handles=[maroon_do_line, sage_do_line, darkgreen_do_line, darkslategray_do_line])

# setting numberical limits on the axes
ax1.set_ylim(0,3000)
ax2.set_ylim(20,29)
ax3.set_ylim(20,29)
ax4.set_ylim(20,29)

# saving figure to results
plt.savefig('../Results/zoo_15_S.pdf')

plt.show()

# %%
fig = plt.figure(figsize=(12, 7))

# Adding a title to the graph
plt.suptitle('2015 Zooplankton and Dissolved Oxygen', fontsize=30, y=1.05)

# layering the three axes, which contain the three varaibles, on top of one another to create a single subplot
# layering completed with twinx() method
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()


# plotting the 3 variables into the predetermined plot outlined above
# Setting the color and width of lines on the graph
ax1.plot(zoo_2015.index, zoo_2015.Total, 'maroon', linewidth =3)
ax2.plot(dis_oxy_2015.index, dis_oxy_2015.m_0, 'sage', linewidth=3)
ax3.plot(dis_oxy_2015.index, dis_oxy_2015.m_5, 'darkgreen', linewidth=3)
ax4.plot(dis_oxy_2015.index, dis_oxy_2015.m_10, 'darkslategray', linewidth=3)

# Adjusting the color of the axes ticks to match line color
ax1.xaxis.set_tick_params(labelcolor='k', size=18)
ax1.yaxis.set_tick_params(labelcolor='k', size=18)
ax2.yaxis.set_tick_params(labelcolor='k', size=18)

# removing the axes ticks on the left and bottom of the graph
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

# removing the axes ticks from the other spines of data
#ax2.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax4.yaxis.set_visible(False)

# Making axes labels, selecting their color, and selecting their size
ax1.set_xlabel('Date', fontsize=20)
ax1.set_ylabel('Zooplankton Abundance' + ' (/m$^3$)', fontsize = 18, color ='k')
ax2.set_ylabel('Dissolved Oxygen' + ' (mg/L)', fontsize = 18, color ='k')

# creating handles for each of the lines in the graph. This is in preperation for making a legend
maroon_do_line = mlines.Line2D([], [], color='maroon', marker='', linewidth=3, markersize=20, label='Zooplankton Abundance')
sage_do_line = mlines.Line2D([], [], color='sage', marker='', linewidth=3, markersize=20, label='Dissolved Oxygen at Surface')
darkgreen_do_line = mlines.Line2D([], [], color='darkgreen', marker='', linewidth=3, markersize=20, label='Dissolved Oxygen at 5m depth')
darkslategray_do_line = mlines.Line2D([], [], color='darkslategray', marker='', linewidth=3, markersize=20, label='Dissolved Oxygen at 10m depth')

# Putting handles in legend
plt.legend(handles=[maroon_do_line, sage_do_line, darkgreen_do_line, darkslategray_do_line])

# setting numberical limits on the axes
ax1.set_ylim(0,3000)
ax2.set_ylim(5,11)
ax3.set_ylim(5,11)
ax4.set_ylim(5,11)

# saving figure to results
plt.savefig('../Results/zoo_15_DO.pdf')

plt.show()

# %%
# setting the figure size
fig = plt.figure(figsize=(12, 7))

# Adding a title to the graph
plt.suptitle('2015 Zooplankton and Environmental Characteristics at the Sea Surface', fontsize=30, y=1.05)

# layering the three axes, which contain the three varaibles, on top of one another to create a single subplot
# layering completed with twinx() method
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()

# plotting the 3 variables into the predetermined plot outlined above
# Setting the color and width of lines on the graph
ax1.plot(zoo_2015.index, zoo_2015.Total, 'maroon', linewidth =3)
ax2.plot(dis_oxy_2015.index, dis_oxy_2015.m_0, 'sage', linewidth=3)
ax3.plot(sal_2015.index, sal_2015.m_0, 'darkgreen', linewidth=3)
ax4.plot(temp_2015.index, temp_2015.m_0, 'darkslategray', linewidth=3)

# Creating new spines of data to measure extra data on different axes
sal_spine = ax3.spines['right']
sal_spine.set_position(('axes', 1.1))
    
temp_spine = ax4.spines['right']
temp_spine.set_position(('axes', 1.2))

# Adjusting the color of the axes ticks to match line color
ax1.xaxis.set_tick_params(labelcolor='k', size=18)
ax1.yaxis.set_tick_params(labelcolor='maroon', size=18)
ax2.yaxis.set_tick_params(labelcolor='sage', size=18)
ax3.yaxis.set_tick_params(labelcolor='darkgreen', size=18)
ax4.yaxis.set_tick_params(labelcolor='darkslategray', size=18)

# removing the axes ticks on the left and bottom of the graph
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

# removing the axes ticks on the other spines of data
#ax2.yaxis.set_visible(False)
#ax3.yaxis.set_visible(False)
#ax4.yaxis.set_visible(False)

# Making axes labels, selecting their color, and selecting their size
ax1.set_xlabel('Date', fontsize=20)
ax1.set_ylabel('Zooplankton Abundance' + ' (/m$^3$)', fontsize = 18, color ='maroon')
ax2.set_ylabel('Sea Surface Dissolved Oxygen' + ' (mg/L)', fontsize = 18, color ='sage')
ax3.set_ylabel('Sea Surface Salinity' + ' (mg/L)', fontsize = 18, color ='darkgreen')
ax4.set_ylabel('Sea Surface temperature' + ' (mg/L)', fontsize = 18, color ='darkslategray')

# setting numberical limits on the axes
ax1.set_ylim(0,3000)
ax2.set_ylim(5,11)
ax3.set_ylim(20,29)
ax4.set_ylim(9,15)

# saving figure to results
plt.savefig('../Results/zoo_15_SEC.pdf')

plt.show()

# %%
# setting the figure size
fig = plt.figure(figsize=(12, 7))

# Adding a title to the graph
plt.suptitle('2015 Zooplankton and Environmental Characteristics at the Sea Surface', fontsize=30, y=1.05)

# layering the three axes, which contain the three varaibles, on top of one another to create a single subplot
# layering completed with twinx() method
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()


# plotting the 3 variables into the predetermined plot outlined above
# Setting the color and width of lines on the graph
ax1.plot(zoo_2015.index, zoo_2015.Total, 'maroon', linewidth =3)
ax2.plot(dis_oxy_2015.index, dis_oxy_2015.m_0, 'sage', linewidth=3)
ax3.plot(sal_2015.index, sal_2015.m_0, 'darkgreen', linewidth=3)
ax4.plot(temp_2015.index, temp_2015.m_0, 'darkslategray', linewidth=3)

# Adjusting the color of the axes ticks to match line color
ax1.xaxis.set_tick_params(labelcolor='k', size=18)
ax1.yaxis.set_tick_params(labelcolor='k', size=18)
ax2.yaxis.set_tick_params(labelcolor='k', size=18)

# removing the axes ticks on the left and bottom of the graph
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

# removing the axes ticks on the other spines of data
#ax2.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax4.yaxis.set_visible(False)

# Making axes labels, selecting their color, and selecting their size
ax1.set_xlabel('Date', fontsize=20)
ax1.set_ylabel('Zooplankton Abundance' + ' (/m$^3$)', fontsize = 18, color ='k')

# creating handles for each of the lines in the graph. This is in preperation for making a legend
maroon_do_line = mlines.Line2D([], [], color='maroon', marker='', linewidth=3, markersize=20, label='Zooplankton Abundance')
sage_do_line = mlines.Line2D([], [], color='sage', marker='', linewidth=3, markersize=20, label='Dissolved Oxygen at Surface')
darkgreen_do_line = mlines.Line2D([], [], color='darkgreen', marker='', linewidth=3, markersize=20, label='Salinity at Surface')
darkslategray_do_line = mlines.Line2D([], [], color='darkslategray', marker='', linewidth=3, markersize=20, label='Water temperatuer at Surface')

# Putting handles in legend
plt.legend(handles=[maroon_do_line, sage_do_line, darkgreen_do_line, darkslategray_do_line])

# setting numberical limits on the axes
ax1.set_ylim(0,3000)
ax2.set_ylim(5,35)
ax3.set_ylim(5,35)
ax4.set_ylim(5,35)

# saving figure to results
plt.savefig('../Results/zoo_15_SEC2.pdf')

plt.show()

# %%
# loading 2009-2012 zooplankton data
zoo_09_12=data_load("../../Computation_Physical_Sciences/Kyles_project/data/Zooplankton_2009-2012.csv")

# %%
# Checking out 2009-2012 zooplankton data
zoo_09_12.head()
# Out:
#             copepods   Cirripedia  euph. larvae  euphausid  Ostracods   \
# DATE
# 2009-02-24      56.36        0.13          0.00       0.51        1.65
# 2009-03-02       1.15       70.23          0.00       0.25        1.27
# 2009-03-10     147.46      134.86         40.08       0.64        1.40
# 2009-03-20      68.58       20.87         41.09       0.64        1.40
# 2009-03-24      88.04       14.89         20.10       1.91       30.15
#
#             Oiklioplera  Bryozoan Larvae(m3)  Decapod  Cnidarians  Annelids  \
# DATE
# 2009-02-24         1.40                 0.13     0.76        2.42      0.00
# 2009-03-02         0.25                 0.38     1.02        1.27      0.00
# 2009-03-10         7.63                 1.78     0.76        0.51      2.93
# 2009-03-20         7.63                 4.71     1.53        0.51      1.40
# 2009-03-24         6.49                 2.29     1.91        1.02      1.53
#
# ...

# %%
# Seperating 2009-2012 zooplankton by year
zoo_2009 = zoo_09_12['2009']
zoo_2010 = zoo_09_12['2010']
zoo_2011 = zoo_09_12['2011']
zoo_2012 = zoo_09_12['2012']

# %% [markdown]
# # Timeseries comparing Zooplankton Blooms
#
# The data manipulations that follow are performed in an attempt to plot all zooplankton timeseries from the years 2009, 2010, 2011, 2012, and 2015 on one graph. A timeseries that compares the timing of zooplankton blooms across years involves overlaying zooplankton blooms from differen years over each other. Right now the data are organized by the datetime function which naturally includes the year in the index. If the indexes are now used to create this timeseries, zooplankton blooms will not be overlain, but will be in a continuous time series. Therefore we must first organize all zooplankton data in terms of a single year so that only the month and day differ between datasets. Then we can compare zooplankton blooms from different years over a single timeline representing the spring bloom season.
#
# In order to get the data in terms of a single year, we can just take the date range for each data set and set the year as 2015. Then we can run this false date range into the each of the data set's index columns. In order to run the date range into the dataset, the data must be run over regular intervals of time (ex. hours, days, weeks etc.). Becuase the data was collected irregularly, we will need to first resample data over a regular interval and then create and run the false date.

# %%
# Resampling 2009-2012 data and averaging data over a week
zoo_2009_w = zoo_2009.resample('W', how=('mean'))
zoo_2010_w = zoo_2010.resample('W', how=('mean'))
zoo_2011_w = zoo_2011.resample('W', how=('mean'))
zoo_2012_w = zoo_2012.resample('W', how=('mean'))

# %%
# Resampling 2015 data and averaging data over a week
zoo_2015_w = zoo_2015.resample('W', how=('mean'))

# %%
# dropping rows with NA data
zoo_2015_w.dropna()
# Out:
#             Cnidaria  Ctenophora  Copoepoda  Cirripedia  Ostracoda  \
# Date
# 2015-04-05        16           1        834         157         90
# 2015-04-12         5           0        742          11          7
# 2015-05-10         8           0        879         456         83
# 2015-05-17         0           1        712         131         71
# 2015-05-24         0           1       1020         361        124
# 2015-05-31         0           1        898         488         43
# 2015-06-07         5           0        476         119         24
# 2015-06-14         0           0        455          75         14
# 2015-06-28         2           0       1563         432         57
#
#             Branchiopoda  Malacostraca  Bryozoan  Phorinida  Chaetognatha  \
# Date
# 2015-04-05             0           161        76          8             2
# 2015-04-12             0            12        47          0            14
# ...

# %%
# obtaining start and end dates for plankton sampling for each year
zoo_2011_w
# Out:
#             copepods   Cirripedia  euph. larvae  euphausid  Ostracods   \
# DATE
# 2011-03-13      170.0         0.0     10.000000        0.0    0.000000
# 2011-03-20      134.0         1.0      6.000000        0.0    1.000000
# 2011-03-27      122.0         1.0      8.000000        0.0    2.000000
# 2011-04-03      412.0         7.0     43.000000        0.0    4.000000
# 2011-04-10       37.0         4.0     14.500000        0.0    2.500000
# 2011-04-17      738.0       143.0    201.000000        0.5    8.500000
# 2011-04-24     1309.0       305.0    925.500000        1.0   51.500000
# 2011-05-01      441.5       176.5    297.500000        0.0   30.500000
# 2011-05-08     1108.5       249.5    210.000000        1.0  207.000000
# 2011-05-15      471.0        63.0    177.666667        4.0   25.666667
# 2011-05-22      438.5       717.5    105.500000       13.5   67.000000
# 2011-05-29      315.5       424.0     43.500000       13.0   53.500000
# ...

# %%
# Changing the year of the data column to 2015 for 2009-2012 data in order to graph all 5 years in one timeseries
zoo_2009_w.index = pd.date_range(start='2015-03-01',end='2015-07-05',freq='W')
zoo_2010_w.index = pd.date_range(start='2015-03-07',end='2015-06-28',freq='W')
zoo_2011_w.index = pd.date_range(start='2015-03-08',end='2015-07-04',freq='W')
zoo_2012_w.index = pd.date_range(start='2015-03-29',end='2015-07-02',freq='W')

# %%
fig = plt.figure(figsize=(12, 7))

# Adding a title to the graph
plt.suptitle('2009-2015 Zooplankton Abundance', fontsize=30, y=1.05)

# layering the three axes, which contain the three varaibles, on top of one another to create a single subplot
# layering completed with twinx() method
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax3 = ax1.twinx()
ax4 = ax1.twinx()
ax5 = ax1.twinx()


# plotting the 3 variables into the predetermined plot outlined above
# Setting the color and width of lines on the graph
ax1.plot(zoo_2015_w.index, zoo_2015_w.Total, 'maroon', linewidth =6)
ax2.plot(zoo_2012_w.index, zoo_2012_w.Total_Zooplankton_Abundance, 'sage', linewidth=3)
ax3.plot(zoo_2011_w.index, zoo_2011_w.Total_Zooplankton_Abundance, 'darkgreen', linewidth=3)
ax4.plot(zoo_2010_w.index, zoo_2010_w.Total_Zooplankton_Abundance, 'darkslategray', linewidth=3)
ax5.plot(zoo_2009_w.index, zoo_2009_w.Total_Zooplankton_Abundance, 'midnightblue', linewidth=3)

# Adjusting the color of the axes ticks to match line color
ax1.xaxis.set_tick_params(labelcolor='k', size=18)
ax1.yaxis.set_tick_params(labelcolor='k', size=18)

# removing axes ticks on the top and bottom of the graph
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

# removing axes ticks on the other spines of data
ax2.yaxis.set_visible(False)
ax3.yaxis.set_visible(False)
ax4.yaxis.set_visible(False)
ax5.yaxis.set_visible(False)

# Making axes labels, selecting their color, and selecting their size
ax1.set_xlabel('Date', fontsize=20)
ax1.set_ylabel('Zooplankton Abundance' + ' (/m$^3$)', fontsize = 18, color ='black')

# Setting the axes date format as displaying only month and day
formatter = DateFormatter('%m/%d')
ax1.xaxis.set_major_formatter(formatter)  

# Setting the axes limits
ax1.set_ylim(0,8000)
ax2.set_ylim(0,8000)
ax3.set_ylim(0,8000)
ax4.set_ylim(0,8000)
ax5.set_ylim(0,8000)

# creating handles for each of the lines in the graph. This is in preperation for making a legend
maroon_line = mlines.Line2D([], [], color='maroon', marker='', linewidth=6, markersize=20, label='2015')
sage_line = mlines.Line2D([], [], color='sage', marker='', linewidth=3, markersize=20, label='2012')
darkgreen_line = mlines.Line2D([], [], color='darkgreen', marker='', linewidth=3, markersize=20, label='2011')
darkslategray_line = mlines.Line2D([], [], color='darkslategray', marker='', linewidth=3, markersize=20, label='2010')
midnightblue_line = mlines.Line2D([], [], color='midnightblue', marker='', linewidth=3, markersize=20, label='2009')

# putting handles in legend
plt.legend(handles=[maroon_line, sage_line, darkgreen_line, darkslategray_line, midnightblue_line])

# saving figure to results
plt.savefig('../Results/2009-2015_zooplankton_abundance.pdf')

plt.show()
